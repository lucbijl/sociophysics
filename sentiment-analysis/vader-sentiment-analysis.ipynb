# %% [markdown]
# # Sentiment analysis with VADER
#
# Using the VADER sentiment analysis tool on a dataset.
#
# Written by Luc Bijl.

# %% [markdown]
# Importing relevant packages and retrieving IMDB testing dataset and taking a sample.

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import os
import random
import re
import nltk
import pandas as pd

test_dataset = "../datasets/aciimdb/test"

reviews = []
labels = []

for sentiment in ['pos','neg']:
    sentiment_dir = os.path.join(test_dataset,sentiment)

    for filename in os.listdir(sentiment_dir):
        if filename.endswith('.txt'):
            with open(os.path.join(sentiment_dir,filename),'r',encoding='utf-8') as file:
                review = file.read()
                sentiment_score = int(filename[:-4].split('_')[1])

                labels.append(sentiment_score)
                reviews.append(review)

data = {'Review': reviews, 'Sentiment': labels}
df_data = pd.DataFrame(data)

df_data
# Out:
#                                                   Review  Sentiment
# 0      Alex North (John Cassavetes) has problems in r...          7
# 1      I won't go to a generalization, and say it's t...         10
# 2      Movie about two Australian girls--Debbie (Nell...          7
# 3      A bland title disguises this solidly-carpenter...          7
# 4      I was laying in bed, flicking through the chan...          8
# ...                                                  ...        ...
# 24995  The first 2/3 of this film wasn't that dissimi...          2
# 24996  the movie is simply horrible (2/10). Although ...          2
# 24997  I don't recommend watching this movie. It's a ...          1
# 24998  *** Possable spoiler but probably not ***<br /...          3
# 24999  (Warning: Some spoilers ahead.)<br /><br />Wha...          2
#
# [25000 rows x 2 columns]

# %% [markdown]
# Creating a testing sample and normalizing the sentiment to a range of -1 to 1.

# %%
samples = 50
df_test = df_data.sample(n=samples,random_state=42)
df_test.reset_index(drop=True,inplace=True)

def normalize(n):
    normal_n = (n - 5) / 5
    return normal_n

df_test['Normal sentiment'] = normalize(df_test['Sentiment'])

df_test.head()
# Out:
#                                               Review  Sentiment  \
# 0  I can not say this movie was a hilarious, but ...          7
# 1  How do stories this bad get made. That's not a...          3
# 2  The most beautiful film. If one is looking for...         10
# 3  This film was really terrible.<br /><br />Howe...          1
# 4  Writer & director Jay Andrews, a.k.a. Jim Wyno...          1
#
#    Normal sentiment
# 0               0.4
# 1              -0.4
# 2               1.0
# 3              -0.8
# 4              -0.8

# %% [markdown]
# Performing sentiment analysis.

# %%
analyzer = SentimentIntensityAnalyzer()

def analyze_sentiment(text):
    sentiment = analyzer.polarity_scores(text)
    return sentiment['compound']

df_test['VADER sentiment'] = df_test['Review'].apply(analyze_sentiment)

df_test.head()
# Out:
#                                               Review  Sentiment  \
# 0  I can not say this movie was a hilarious, but ...          7
# 1  How do stories this bad get made. That's not a...          3
# 2  The most beautiful film. If one is looking for...         10
# 3  This film was really terrible.<br /><br />Howe...          1
# 4  Writer & director Jay Andrews, a.k.a. Jim Wyno...          1
#
#    Normal sentiment  VADER sentiment
# 0               0.4           0.8321
# 1              -0.4          -0.9664
# 2               1.0           0.9944
# 3              -0.8           0.9646
# 4              -0.8           0.9853

# %%
df_test
# Out:
#                                                Review  Sentiment  \
# 0   I can not say this movie was a hilarious, but ...          7
# 1   How do stories this bad get made. That's not a...          3
# 2   The most beautiful film. If one is looking for...         10
# 3   This film was really terrible.<br /><br />Howe...          1
# 4   Writer & director Jay Andrews, a.k.a. Jim Wyno...          1
# 5   I think together all the reviewers have captur...         10
# 6   I came across this movie while channel surfing...          9
# 7   I initially tuned in to Paranormal State becau...          1
# 8   Like the first one,the team of JACKASS are bac...          7
# 9   The Coen's strike again. I had no presuppositi...          8
# 10  This DVD is missing its calling as a Heineken ...          1
# 11  Freely, from one scene to another, from one st...         10
# 12  When I first saw "Before Night Falls", Javier ...         10
# 13  Very resistible but ultimately harmless film v...          4
# 14  Good movie, great story, great characters, I e...          8
# 15  This movie has a few good performances going f...          3
# 16  A group of friends discover gold deep inside a...          4
# 17  For me, it just didn't seem like GI Joe at all...          2
# 18  hello everyone, all i have to say is that Huma...         10
# 19  Was struck at how even the acting was througho...         10
# 20  I thought Besson's film managed to do without ...          8
# 21  Maybe my rating should have been a 9, but the ...         10
# 22  This is one of the best Czech movies I have ev...         10
# 23  Not a box office success; no-one really knows ...          8
# 24  A touching documentary that puts a human face ...         10
# 25  When the Legends Die is a powerful, moving sto...          3
# 26  I have some great memories watching "Robin of ...         10
# 27  I had seen this movie as a kid and loved it. I...         10
# 28  Okay, enough. Every time I think I've seen a f...          1
# 29  As a lesbian, I am sick and tired of being por...         10
# 30  Hmmm, not a patch on the original from Shaw Br...          2
# 31  I'm relieved the later reviews have turned sou...          1
# 32  I had to rent a couple of movies for my little...          4
# 33  Multiply named and strangely casted, "One Dark...          8
# 34  A surprisingly great cartoon in the same leagu...         10
# 35  Good grief.. to think I've seen it all.. Danny...          4
# 36  This is a very noir kind of episode. It begins...          8
# 37  I have just started watching this show. Its ai...          9
# 38  This is another film I missed out on Italian T...          4
# 39  Not just the money we paid to rent it or actua...          1
# 40  Four holy young men from Mormon country go to ...          8
# 41  I really liked this film about love between tw...         10
# 42  This is one of the more unromantic movies I ha...          2
# 43  I can't knock this film too terribly, because ...          3
# 44  David Tennant and Sarah Parish's brilliant act...         10
# 45  This is a wonderful look, you should pardon th...          8
# 46  * Some spoilers *<br /><br />This movie is som...          3
# 47  Now, I like the Bollywood films and I'm very g...          1
# 48  Sex, drugs, racism and of course you ABC's. Wh...         10
# 49  Given the subject matter of drug addiction Dow...          4
#
#     Normal sentiment  VADER sentiment
# 0                0.4           0.8321
# 1               -0.4          -0.9664
# 2                1.0           0.9944
# 3               -0.8           0.9646
# 4               -0.8           0.9853
# 5                1.0           0.9829
# 6                0.8           0.9740
# 7               -0.8          -0.8487
# 8                0.4          -0.8377
# 9                0.6          -0.0516
# 10              -0.8           0.8869
# 11               1.0           0.9749
# 12               1.0           0.9788
# 13              -0.2           0.9754
# 14               0.6           0.9788
# 15              -0.4           0.9401
# 16              -0.2          -0.9831
# 17              -0.6          -0.5746
# 18               1.0           0.9920
# 19               1.0           0.9346
# 20               0.6           0.9753
# 21               1.0           0.9941
# 22               1.0           0.9233
# 23               0.6           0.7452
# 24               1.0           0.7684
# 25              -0.4          -0.8748
# 26               1.0           0.9962
# 27               1.0           0.9725
# 28              -0.8           0.6441
# 29               1.0           0.9909
# 30              -0.6          -0.8023
# 31              -0.8           0.4205
# 32              -0.2          -0.7078
# 33               0.6           0.0516
# 34               1.0           0.9422
# 35              -0.2           0.8971
# 36               0.6           0.9863
# 37               0.8           0.9963
# 38              -0.2          -0.9934
# 39              -0.8          -0.1081
# 40               0.6           0.9186
# 41               1.0           0.9565
# 42              -0.6           0.2876
# 43              -0.4           0.8529
# 44               1.0           0.7533
# 45               0.6           0.9738
# 46              -0.4           0.9961
# 47              -0.8           0.8646
# 48               1.0           0.7606
# 49              -0.2          -0.9874

# %%
from scipy.stats import pearsonr


correlation, _ = pearsonr(df_test['VADER sentiment'],df_test['Normal sentiment'])

print(f"Sample correlation: {correlation:.2f}")
# Out:
# Sample correlation: 0.46
